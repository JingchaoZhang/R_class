# %%
import pandas as pd
# %matplotlib notebook

import matplotlib.pyplot as plt

# %%
data = pd.read_csv('us-counties.csv')

# %%
georgia = data[data['state'] == 'Georgia']
top5 = georgia.groupby('county')['cases'].max().sort_values(ascending=False).head(5).index.tolist()
top5
#georgia['county'].unique()
# Out:
# ['Gwinnett', 'Fulton', 'DeKalb', 'Cobb', 'Hall']

# %%
for n, i in enumerate(top5):
    value = georgia.set_index('county').loc[i]['cases'].tolist()
    date = georgia.set_index('county').loc[i]['date'].tolist()
    #pd.DataFrame({'date': date, 'cases': value}).set_index('date').plot()
    
    #plt.plot(date, value)
    #plt.show()

# %%
decatur = data[(data['county'] == 'Decatur') & (data['state'] == 'Georgia')].set_index('date')['cases']
decatur
# Out:
# date
# 2020-03-25      1
# 2020-03-26      2
# 2020-03-27      3
# 2020-03-28      4
# 2020-03-29      4
#              ...
# 2020-06-14    224
# 2020-06-15    224
# 2020-06-16    236
# 2020-06-17    235
# 2020-06-18    239
# Name: cases, Length: 86, dtype: int64

# %%
Lincoln = data[(data['county'] == 'Lincoln') & (data['state'] == 'Nebraska')].set_index('date')['cases']
Lincoln
# Out:
# date
# 2020-03-18     1
# 2020-03-19     3
# 2020-03-20     3
# 2020-03-21     3
# 2020-03-22     3
#               ..
# 2020-06-14    53
# 2020-06-15    53
# 2020-06-16    53
# 2020-06-17    54
# 2020-06-18    54
# Name: cases, Length: 93, dtype: int64

# %%
decatur.plot()
Lincoln.plot()

plt.legend(['Decatur, GA', 'Lincoln, NE'])

plt.gca().set_title('Cumulative covid19 cases in Decatur, GA and Lincoln, NE', pad = 20)
plt.gca().set_ylabel('Number of cases')
plt.gca().set_xlabel('Date')

plt.savefig('covid19.png')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
